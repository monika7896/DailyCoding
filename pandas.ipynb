# %% [markdown]
# <a href="https://colab.research.google.com/github/monika7896/DailyCoding/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('dummy.csv')
df
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0     SSSQ.SFMN1111CA  2004.06    1248.356         NaN      F  dollars
# 1     SSSQ.SFMN1111CA  2004.09    1220.571         NaN      F  dollars
# 2     SSSQ.SFMN1111CA  2004.12    1263.820         NaN      F  dollars
# 3     SSSQ.SFMN1111CA  2005.03    1146.156         NaN      F  dollars
# 4     SSSQ.SFMN1111CA  2005.06    1382.692         NaN      F  dollars
# ...               ...      ...         ...         ...    ...      ...
# 1180  SSSQ.SFRS2121CT  2022.12         NaN         NaN      C  dollars
# 1181  SSSQ.SFRS2121CT  2023.03         NaN         NaN      C  dollars
# 1182  SSSQ.SFRS2121CT  2023.06         NaN         NaN      C  dollars
# 1183  SSSQ.SFRS2121CT  2023.09         NaN         NaN      C  dollars
# 1184  SSSQ.SFRS2121CT  2023.12         NaN         NaN      C  dollars
#
#       Magnitude                                    Subject  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1185 entries, 0 to 1184
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  1185 non-null   object
#  1   Period            1185 non-null   float64
#  2   Data_value        1105 non-null   float64
#  3   Suppressed        0 non-null      float64
#  4   STATUS            1185 non-null   object
#  5   UNITS             1185 non-null   object
#  6   Magnitude         1185 non-null   int64
#  7   Subject           1185 non-null   object
#  8   Group             1185 non-null   object
#  9   Series_title_1    1185 non-null   object
#  10  Series_title_2    1185 non-null   object
#  11  Series_title_3    1185 non-null   object
#  12  Series_title_4    1185 non-null   object
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 129.7+ KB

# %%
df.head(3)
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0  SSSQ.SFMN1111CA  2004.06    1248.356         NaN      F  dollars
# 1  SSSQ.SFMN1111CA  2004.09    1220.571         NaN      F  dollars
# 2  SSSQ.SFMN1111CA  2004.12    1263.820         NaN      F  dollars
#
#    Magnitude                                    Subject  \
# 0          6  Selected Services Survey (ANZSIC06) - SSS
# 1          6  Selected Services Survey (ANZSIC06) - SSS
# 2          6  Selected Services Survey (ANZSIC06) - SSS
#
#                                              Group  \
# 0  Industry sales - Subannual Financial Collection
# 1  Industry sales - Subannual Financial Collection
# 2  Industry sales - Subannual Financial Collection
#
#                                       Series_title_1  \
# 0  Scientific, Architectural and Engineering Serv...
# 1  Scientific, Architectural and Engineering Serv...
# 2  Scientific, Architectural and Engineering Serv...
#
# ...

# %%
df.tail()
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 1180  SSSQ.SFRS2121CT  2022.12         NaN         NaN      C  dollars
# 1181  SSSQ.SFRS2121CT  2023.03         NaN         NaN      C  dollars
# 1182  SSSQ.SFRS2121CT  2023.06         NaN         NaN      C  dollars
# 1183  SSSQ.SFRS2121CT  2023.09         NaN         NaN      C  dollars
# 1184  SSSQ.SFRS2121CT  2023.12         NaN         NaN      C  dollars
#
#       Magnitude                                    Subject  \
# 1180          6  Selected Services Survey (ANZSIC06) - SSS
# 1181          6  Selected Services Survey (ANZSIC06) - SSS
# 1182          6  Selected Services Survey (ANZSIC06) - SSS
# 1183          6  Selected Services Survey (ANZSIC06) - SSS
# 1184          6  Selected Services Survey (ANZSIC06) - SSS
#
#                                                 Group  \
# 1180  Industry sales - Subannual Financial Collection
# 1181  Industry sales - Subannual Financial Collection
# ...

# %%
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df[['Series_reference', 'Period', 'Data_value', 'Suppressed']].head(5)
# Out:
#   Series_reference   Period  Data_value  Suppressed
# 0  SSSQ.SFMN1111CA  2004.06    1248.356         NaN
# 1  SSSQ.SFMN1111CA  2004.09    1220.571         NaN
# 2  SSSQ.SFMN1111CA  2004.12    1263.820         NaN
# 3  SSSQ.SFMN1111CA  2005.03    1146.156         NaN
# 4  SSSQ.SFMN1111CA  2005.06    1382.692         NaN
